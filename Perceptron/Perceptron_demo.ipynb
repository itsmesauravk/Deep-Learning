# %%
import pandas as pd

# %%
df = pd.read_csv('mushroom.csv')

# %%
df.head()
# Out:
#    cap-diameter  cap-shape  gill-attachment  gill-color  stem-height  \
# 0          1372          2                2          10     3.807467
# 1          1461          2                2          10     3.807467
# 2          1371          2                2          10     3.612496
# 3          1261          6                2          10     3.787572
# 4          1305          6                2          10     3.711971
#
#    stem-width  stem-color    season  class
# 0        1545          11  1.804273      1
# 1        1557          11  1.804273      1
# 2        1566          11  1.804273      1
# 3        1566          11  1.804273      1
# 4        1464          11  0.943195      1

# %%
df.shape
# Out:
# (54035, 9)

# %%
X = df.iloc[:, : -1]

# %%
y = df.iloc[:, -1]

# %%
X.shape
# Out:
# (54035, 8)

# %%
y.shape
# Out:
# (54035,)

# %%
from sklearn.linear_model import Perceptron

# %%
pc = Perceptron()

# %%
pc.fit(X,y)
# Out:
# Perceptron()

# %%
#  bias, y-intercept
pc.intercept_
# Out:
# array([10620.])

# %%
#weighs
pc.coef_
# Out:
# array([[  1825.        , -11159.        ,  13307.        ,
#          12423.        ,  36995.50922392,  -2470.        ,
#            717.        ,   4463.56077163]])

# %% [markdown]
# ## if i take only two diamensional data

# %%
X = df[['cap-diameter', 'stem-width']]

# %%
X.shape
# Out:
# (54035, 2)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sns.scatterplot(data=df, x=df['cap-diameter'], y=df['stem-width'], hue=df['class'])
# Out:
# <Axes: xlabel='cap-diameter', ylabel='stem-width'>

# %%
pc1 = Perceptron()

# %%
pc1.fit(X,y)
# Out:
# Perceptron()

# %%
pc1.intercept_
# Out:
# array([20777.])

# %%
pc1.coef_
# Out:
# array([[ 988., 1080.]])

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X.values,y.values, clf=pc1, legend=2)
# Out:
# D:\Applications\Python\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but Perceptron was fitted with feature names
#   warnings.warn(
# <Axes: >

# %% [markdown]
# ## Result is worse this is only for Perception Understanding
